# %% [markdown]
# <a href="https://colab.research.google.com/github/LuisFelipeVelasco/Ant-Detection-and-Fungus-Analysis-Using-Machine-Learning/blob/main/Notebooks/binary_decision_tree_from_scratch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **DECISION TREE**
